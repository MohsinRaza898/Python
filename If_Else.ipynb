# %% [raw]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
service_years = int(input("enter your service years :"))
salary = int(input("enter your salary :"))

if (salary >= 5):
  bonus = salary * 0.05
  print(f"you get {bonus} bonus")
else:
  print ("your service in less then 5 years sorry")
# Out:
# enter your service years :6
# enter your salary :100000
# you get 5000.0 bonus

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user)

# %%
age = int(input("enter your age :"))

if (age >=18):
  print("you are eligible for vote")
else :
  print("you are not eligible for vote")
# Out:
# enter your age :15
# you are not eligible for vote

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
num = float(input("enter a number :"))

if (num%2==0):
  print("given number is even")
else :
  print("given number is odd")
# Out:
# enter a number :12.0
# given number is even

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
num = float(input("enter a number :"))

if (num%7==0):
  print("given number is divisible by 7")
else:
  print("given number is not divisible by 7")
# Out:
# enter a number :56
# given number is divisible by 7

# %% [raw]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
num = float(input("enter a number :"))

if num%5==0:
  print("Hello")
else:
  print("Bye")
# Out:
# enter a number :25
# Hello

# %% [raw]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# upto 100 units                                             no charge
#  after 100 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.2000
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.250

# %%
number_of_units = int(input("enter numbers of units :"))

if(number_of_units >100 and number_of_units<=200):
  bill_amount= (200-100)*5
  print(f"{number_of_units} units of bill amount is :",bill_amount)

elif(number_of_units>200):
  bill_amount=(number_of_units-200)*10 + (200-100)*5
  print(f"{number_of_units} units of bill amount is :",bill_amount)

else:
  print(f"{number_of_units} units has no charges")
# Out:
# enter numbers of units :500
# 500 units of bill amount is : 3500

# %% [raw]
# 7) Write a program to display the last digit of a number.

# %%
num = int(input("enter a number :"))
print("last digit of given number is :", num % 10)
# Out:
# enter a number :1232344557
# last digit of given number is : 7

# %%
num = input("enter a number :") #str
print("last digit of given number is :", num[-1])
# Out:
# enter a number :321
# last digit of given number is : 1

# %% [raw]
# Q8. Write a program to check whether the last digit of a number( entered by user ) is
# divisible by 3 or not.

# %%
num = int(input("enter a number :"))
last_digit = num % 10
print("last_digit is :",last_digit)
if(last_digit % 3==0):
  print("last digit is divisible by 3")
else:
  print("last digit is not divisible by 3")
# Out:
# enter a number :2345
# last_digit is : 5
# last digit is not divisible by 3

# %% [raw]
# 9) Take values of length and breadth of a rectangle from user and check if it is square or not.

# %%
length = float(input("enter length :"))
breadth = float(input("enter breadth :"))

if (length == breadth):
  print("It is square")
else:
  print("It is not square")
# Out:
# enter length :23
# enter breadth :23
# It is square

# %% [raw]
# 10) Take two int values from user and print greatest among them.

# %%
num1 = int(input("enter first number :"))
num2 = int(input("enter second number :"))

if (num1 > num2):
  print(f"{num1} is greter from {num2}")
else:
  print(f"{num2} is greter from {num1}")
# Out:
# enter first number :56
# enter second number :45
# 56 is greter from 45

# %% [raw]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
units =int(input("How manay units purchased? "))
per_unit = 100
purchased_quantity = units * per_unit
if (purchased_quantity > 1000):
  purchased_quantity -= purchased_quantity * 0.10
  print(purchased_quantity)
else:
  print("no discount")
# Out:
# How manay units purchased? 13
# 1170.0

# %% [raw]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks = int(input("enter marks for grade :"))

if(marks >= 80):
  print("your grade is A")

elif(marks >= 60 and marks < 80):
  print("your grade is B")

elif(marks >= 50 and marks < 60):
  print("your grade is C")


elif(marks >= 45 and marks < 50):
  print("your grade is D")

elif(marks >= 25 and marks < 45):
  print("your grade is E")

else:
  print("your grade is F")
# Out:
# enter marks for grade :56
# your grade is C

# %%
marks = int(input("enter marks for grade :"))
grade = None

if(marks >= 80):
  grade = "A"

elif(marks >= 60 and marks < 80):
  grade = "B"

elif(marks >= 50 and marks < 60):
  grade = "C"

elif(marks >= 45 and marks < 50):
  grade = "D"

elif(marks >= 25 and marks < 45):
  grade = "E"

else:
  grade = "F"

  print(grade)
# Out:
# enter marks for grade :76

# %% [raw]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
p1 = int(input("Enter your age :"))
p2 = int(input("Enter your age :"))
p3 = int(input("Enter your age :"))

if (p1 > p2 and p1 > p3):
  print("p1 is oldest among them")

elif (p2 > p1 and p2 > p3):
  print("p2 is oldest among them")

else:
  print("p3 is oldest among them")


if (p1 < p2 and p1 < p3):
  print("p1 is youngest among them")

elif (p2 < p1 and p2 < p3):
  print("p2 is youngest among them")

else:
  print("p3 is youngest among them")
# Out:
# Enter your age :34
# Enter your age :20
# Enter your age :45
# p3 is oldest among them
# p2 is youngest among them

# %% [raw]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# Number of classes held
#
# Number of classes attended.
#
# And print
#
# percentage of class attended
#
# Is student is allowed to sit in exam or not.

# %%
number_of_classes_attended = int(input("enter number of classes attended :"))
number_of_classes_held = int(input("enter number of classes held :"))
percentage_of_class_attended = (number_of_classes_attended / number_of_classes_held ) *100
print(percentage_of_class_attended)

if (percentage_of_class_attended >= 75):
  print("Student is allowed to sit in exam")
else:
  print("Student is not allowed to sit in exam")
# Out:
# enter number of classes attended :32
# enter number of classes held :42
# 76.19047619047619
# Student is allowed to sit in exam

# %% [raw]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
number_of_classes_attended = int(input("enter number of classes attended :"))
number_of_classes_held = int(input("enter number of classes held :"))
percentage_of_class_attended = (number_of_classes_attended / number_of_classes_held ) *100
medical_cause = input("enter your madical cause :")
print("percentage_of_class_attended is :",percentage_of_class_attended)


if (percentage_of_class_attended >= 75 and medical_cause == "y"):
  print("Student is allowed to sit in exam")

if (percentage_of_class_attended >= 75 and medical_cause != "y"):
  print("Attendence percentage is :",percentage_of_class_attended)
  print("Due to medical cause,Student is allowed to sit in exam")
else:
  print("Student is not allowed to sit in exam")
# Out:
# enter number of classes attended :31
# enter number of classes held :42
# enter your madical cause :n
# percentage_of_class_attended is : 73.80952380952381
# Student is not allowed to sit in exam

# %% [raw]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
year = int(input("enter year to check leap year or not :"))

if(year < 1000 and year % 4 ==0):
  print("given year is leap year ")

elif (year >=1000 and year % 400 ==0):
  print("given year is leap year ")
else:
   print("given year is not a leap year")
# Out:
# enter year to check leap year or not :10000
# given year is leap year

# %% [raw]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input("enter your age :"))
gender = input("enter your gender (M/F) :")
marital_status = input("enter your marital status (Y/N) :")

if(gender == "F" or gender == "f"):
  print("you will work only in urban areas")
elif(gender == "M" or gender == "m"):
  if(age >=20 and age <40):
    print("you may work at anywhere")
  elif(age >=40 and age <60):
    print("you will work in urban areas only")
  else:
    print("ERROR")
else:
  print("ERROR")
# Out:
# enter your age :50
# enter your gender (M/F) :m
# enter your marital status (Y/N) :n
# you will work in urban areas only
